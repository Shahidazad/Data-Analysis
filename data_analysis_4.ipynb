# %%
with open('data1.txt','r') as f:
    print(f.readline())
# Out:
# "Date(UTC)","UnixTimeStamp","Value"

# %%
with open('data1.txt','r') as f:
    for i,line in enumerate(f.readlines()):
        if  (i<10):
            print(line)
# Out:
# "Date(UTC)","UnixTimeStamp","Value"
#
# "4/2/2017","1491091200","48.55"
#
# "4/3/2017","1491177600","44.13"
#
# "4/4/2017","1491264000","44.43"
#
# "4/5/2017","1491350400","44.90"
#
# "4/6/2017","1491436800","43.23"
#
# "4/7/2017","1491523200","42.31"
#
# "4/8/2017","1491609600","44.37"
#
# "4/9/2017","1491696000","43.72"
#
# "4/10/2017","1491782400","43.74"

# %%
with open('data1.txt','r') as f:
    for i,line in enumerate(f.readlines()):
        if  (i<10):
            price=line.split(',')
            time=price[1]
            print(time)
# Out:
# "UnixTimeStamp"
# "1491091200"
# "1491177600"
# "1491264000"
# "1491350400"
# "1491436800"
# "1491523200"
# "1491609600"
# "1491696000"
# "1491782400"

# %%
pd.read_csv?
# Out:
# Object `pd.read_csv` not found.

# %%
import pandas as pd

# %%
url='http://localhost:8888/notebooks/data_analysis_4.ipynb'
pd.read_csv(url).head()

# %%
# save to csv
df.to_csv('name.csv',index=None)

# %%
import sqlite3
conn=sqlite3.connect('chinook.db')

# %%
cur=conn.cursor()

# %%
cur.execute('SELECT * FROM employees LIMIT 5;')

# %%
result=cur.fetchall()

# %%
result
# Out:
# []

# %%
df=pd.DataFrame(result)

# %%
cur.close()
conn.close()

# %%
# # using pandas
conn=sqlite3.connect('sakila-schema.db')
df=pd.read_sql('SELECT * FROM payment LIMIT 5',conn)

# %%
# data in html format

# %%
html_string ='<input type="text" class="form-control bfh-phone" data-format="+7(ddd)-ddd-dd-dd" />'

# %%
from IPython.core.display import display,HTML
display(HTML(html_string))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6484\2555136287.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <input type="text" class="form-control bfh-phone" data-format="+7(ddd)-ddd-dd-dd" />

# %%
df=pd.read_html(html_string)

# %%
html_url='https://www.bing.com/search?q=html+data+format&form=ANNTH1&refig=ed3f822c4eb043f1bda39e8c4eee229e'

# %%
tab=pd.read_html(html_url)

# %%
tab
# Out:
# [                           Unnamed: 0      TAG  \
#  0                         Description      <b>
#  1                   Defines bold text     <em>
#  2             Defines emphasized text      <i>
#  3  Defines a part of text in an a ...  <small>
#
#                            DESCRIPTION
#  0                   Defines bold text
#  1             Defines emphasized text
#  2  Defines a part of text in an a ...
#  3                Defines smaller text  ,
#           Unnamed: 0            STRING         DATE AND/OR TIME
#  0  Date and/or time        2005-06-07             June 7, 2005
#  1         [details]             08:45                  8:45 AM
#  2         [details]          08:45:25   8:45 AM and 25 seconds
#  3         [details]  0033-08-04T03:40  3:40 AM on August 4, 33,
#                                                     0
#  0  python - Django - Datatable multiple models wi...
#  1  javascript - Google apps script html script ta...]

# %%
import requests
h_u='https://en.wikipedia.org/wiki/The_Simpsons'

# %%
r=requests.get(h_u)
w=pd.read_html(r.text)

# %%
w
# Out:
# [            The Simpsons                                     The Simpsons.1
#  0                    NaN                                                NaN
#  1                  Genre                             Animated sitcom Satire
#  2             Created by                                      Matt Groening
#  3               Based on                The Simpsons shortsby Matt Groening
#  4           Developed by            James L. Brooks Matt Groening Sam Simon
#  5              Voices of  Dan Castellaneta Julie Kavner Nancy Cartwright...
#  6   Theme music composer                                       Danny Elfman
#  7          Opening theme                               "The Simpsons Theme"
#  8              Composers  Richard Gibbs (1989–1990)Alf Clausen (1990–201...
#  9      Country of origin                                      United States
#  10     Original language                                            English
# ...

# %%
len(w)
# Out:
# 42

# %%
w[1]
# Out:
#    Season            No. ofepisodes    Originally aired                     \
#    Season            No. ofepisodes     Season premiere      Season finale
#    Season   Season.1 No. ofepisodes     Season premiere      Season finale
# 0       1    1989–90             13   December 17, 1989       May 13, 1990
# 1       2    1990–91             22    October 11, 1990      July 11, 1991
# 2       3    1991–92             24  September 19, 1991    August 27, 1992
# 3       4    1992–93             22  September 24, 1992       May 13, 1993
# 4       5    1993–94             22  September 30, 1993       May 19, 1994
# 5       6    1994–95             25   September 4, 1994       May 21, 1995
# 6       7    1995–96             25  September 17, 1995       May 19, 1996
# 7       8    1996–97             25    October 27, 1996       May 18, 1997
# 8       9    1997–98             25  September 21, 1997       May 17, 1998
# ...

# %%
df=w[1]

# %%
df
# Out:
#    Season            No. ofepisodes    Originally aired                     \
#    Season            No. ofepisodes     Season premiere      Season finale
#    Season   Season.1 No. ofepisodes     Season premiere      Season finale
# 0       1    1989–90             13   December 17, 1989       May 13, 1990
# 1       2    1990–91             22    October 11, 1990      July 11, 1991
# 2       3    1991–92             24  September 19, 1991    August 27, 1992
# 3       4    1992–93             22  September 24, 1992       May 13, 1993
# 4       5    1993–94             22  September 30, 1993       May 19, 1994
# 5       6    1994–95             25   September 4, 1994       May 21, 1995
# 6       7    1995–96             25  September 17, 1995       May 19, 1996
# 7       8    1996–97             25    October 27, 1996       May 18, 1997
# 8       9    1997–98             25  September 21, 1997       May 17, 1998
# ...
